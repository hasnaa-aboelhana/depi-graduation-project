# %% [markdown]
# <a href="https://colab.research.google.com/github/hasnaa-aboelhana/depi-graduation-project/blob/main/resnet152v2_eurosat_v3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Define a local folder to save everything persistently for this session
SAVE_DIR = 'EuroSAT_Models'
os.makedirs(SAVE_DIR, exist_ok=True)

# %% [markdown]
# # Land-Cover Classification with EuroSAT - ResNet152V2 (v3.3 - Auto-Resume)
#
# This notebook trains and evaluates a **ResNet152V2** model on the EuroSAT RGB
# dataset for land-cover classification (10 classes, 64x64 satellite patches).
#
# It is one model in a larger comparison study (ResNet50, ResNet50V2,
# ResNet152V2, VGG16, VGG19, etc.). Each model lives in its own self-contained
# notebook so it can be run and graded independently; this one covers
# **ResNet152V2 only**.
#
# **Pipeline:**
# 1. Download the dataset (via `kagglehub`)
# 2. Split into train/test sets and set up data generators
# 3. Build a ResNet152V2-based classifier (ImageNet weights + custom head)
# 4. Train in two stages - frozen backbone, then full fine-tuning
# 5. Evaluate on the test set and save the trained model
#
# **v2 improvements:** This version automatically saves progress after
# every epoch and resumes from the last checkpoint if the Kaggle session
# crashes or disconnects. Just re-run all cells - no manual changes needed.
#
# **Reference:** Helber et al., *EuroSAT: A Novel Dataset and Deep Learning
# Benchmark for Land Use and Land Cover Classification*, IEEE JSTARS, 2019.

# %% [markdown]
# ## 1. Setup
#
# Import the libraries used throughout this notebook.

# %%
import os
import re
import shutil

from tqdm import tqdm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import (
    precision_recall_fscore_support,
    confusion_matrix,
    f1_score,
    fbeta_score,
    accuracy_score,
)

import tensorflow as tf
from keras.models import Model
from keras.layers import Dense, Dropout, GlobalAveragePooling2D
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger
from keras.optimizers import Adam
from keras.optimizers.schedules import CosineDecayRestarts
from keras.applications import ResNet152V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# **GPU configuration.** If a GPU is available, restrict TensorFlow to the
# first one and enable soft device placement so ops fall back to CPU when
# needed.

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPU")
    except RuntimeError as e:
        # Visible devices must be set before GPUs have been initialized
        print(e)

tf.config.set_soft_device_placement(True)
# Out:
# 1 Physical GPUs, 1 Logical GPU

# %% [markdown]
# ## 2. Dataset
#
# Download the EuroSAT RGB dataset from Kaggle via `kagglehub`. The helper
# below downloads the dataset (skipping the download if it's already cached
# locally) and locates the directory that directly contains the 10 class
# sub-folders, regardless of the exact folder layout inside the archive.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nilesh789/eurosat-rgb")
print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'eurosat-rgb' dataset.
# Path to dataset files: /kaggle/input/eurosat-rgb

# %%
# Locate the folder that directly contains the 10 class sub-directories
# (the archive layout can nest the images one level deeper, e.g. .../2750).
EXPECTED_CLASSES = {
    'AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial',
    'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake',
}

DATASET = None
for root, dirs, _ in os.walk(path):
    if EXPECTED_CLASSES.issubset(set(dirs)):
        DATASET = root
        break

if DATASET is None:
    raise FileNotFoundError(
        f"Could not locate the EuroSAT class folders under: {path}"
    )

LABELS = sorted(os.listdir(DATASET))
print("Dataset directory:", DATASET)
print("Classes found:", LABELS)
# Out:
# Dataset directory: /kaggle/input/eurosat-rgb/2750
# Classes found: ['AnnualCrop', 'Forest', 'HerbaceousVegetation', 'Highway', 'Industrial', 'Pasture', 'PermanentCrop', 'Residential', 'River', 'SeaLake']

# %% [markdown]
# ## 3. Train / Test Split
#
# Hold out 20% of the images for testing using a stratified split, so the
# class proportions are preserved in both subsets. Images are physically
# copied into `training/` and `testing/` folders (each with one sub-folder
# per class) so Keras's `ImageDataGenerator.flow_from_directory` can be used
# directly.

# %%
TRAIN_DIR = 'training'
TEST_DIR = 'testing'
BATCH_SIZE = 64
NUM_CLASSES = len(LABELS)
INPUT_SHAPE = (64, 64, 3)
CLASS_MODE = 'categorical'

# Check if the train/test split already exists (idempotent for Kaggle/session restarts)
_train_count = sum(len(f) for _, _, f in os.walk(TRAIN_DIR)) if os.path.exists(TRAIN_DIR) else 0
_test_count = sum(len(f) for _, _, f in os.walk(TEST_DIR)) if os.path.exists(TEST_DIR) else 0
SPLIT_ALREADY_DONE = _train_count > 0 and _test_count > 0

if SPLIT_ALREADY_DONE:
    print(f"Existing split found: {_train_count} train / {_test_count} test images. Skipping re-split.")
else:
    # Clean up any leftover partial files to prevent data leakage
    for split_dir in (TRAIN_DIR, TEST_DIR):
        if os.path.exists(split_dir):
            shutil.rmtree(split_dir)

    # Create training and testing directories (with one sub-folder per class)
    for split_dir in (TRAIN_DIR, TEST_DIR):
        os.makedirs(split_dir, exist_ok=True)
        for label in LABELS:
            os.makedirs(os.path.join(split_dir, label), exist_ok=True)

# %%
if not SPLIT_ALREADY_DONE:
    # Map every image path to its class label
    data = {}
    for label in LABELS:
        for img in os.listdir(os.path.join(DATASET, label)):
            data[os.path.join(DATASET, label, img)] = label

    X = pd.Series(list(data.keys()))
    y = pd.get_dummies(pd.Series(data.values()))

    split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=69)

    # Perform the stratified split and copy files into TRAIN_DIR / TEST_DIR
    for train_idx, test_idx in split.split(X, y):

        train_paths = X[train_idx]
        test_paths = X[test_idx]

        new_train_paths = [
            p.replace(DATASET, TRAIN_DIR) for p in train_paths
        ]
        new_test_paths = [
            p.replace(DATASET, TEST_DIR) for p in test_paths
        ]

        train_path_map = list(zip(train_paths, new_train_paths))
        test_path_map = list(zip(test_paths, new_test_paths))

        print("Copying training files...")
        for src, dst in tqdm(train_path_map):
            if not os.path.exists(dst):
                shutil.copy(src, dst)

        print("Copying testing files...")
        for src, dst in tqdm(test_path_map):
            if not os.path.exists(dst):
                shutil.copy(src, dst)
else:
    print("Skipping file copy (split already exists).")
# Out:
# Copying training files...
# 100%|██████████| 21600/21600 [01:10<00:00, 307.87it/s]
# Copying testing files...
# 100%|██████████| 5400/5400 [00:16<00:00, 317.89it/s]

# %% [markdown]
# **Data generators.** The training generator applies on-the-fly data
# augmentation (rotation, shifts, shear, zoom, flips) to reduce overfitting;
# the test generator only rescales pixel values, since augmentation should
# not be applied at evaluation time.

# %%
train_gen = ImageDataGenerator(
    preprocessing_function=preprocess_input,
    rotation_range=360,
    horizontal_flip=True,
    vertical_flip=True,
    brightness_range=[0.8, 1.2],
    channel_shift_range=10.0,
)

train_generator = train_gen.flow_from_directory(
    directory=TRAIN_DIR,
    target_size=(64, 64),
    batch_size=BATCH_SIZE,
    class_mode=CLASS_MODE,
    color_mode='rgb',
    shuffle=True,
    seed=69,
)

# Test generator: preprocessing only, no augmentation, used for validation/evaluation
test_gen = ImageDataGenerator(preprocessing_function=preprocess_input)

test_generator = test_gen.flow_from_directory(
    directory=TEST_DIR,
    target_size=(64, 64),
    batch_size=BATCH_SIZE,
    class_mode=CLASS_MODE,
    color_mode='rgb',
    shuffle=False,
    seed=69,
)
# Out:
# Found 21600 images belonging to 10 classes.
# Found 5400 images belonging to 10 classes.

# %%
print(train_generator.class_indices)
np.save('class_indices', train_generator.class_indices)
# Out:
# {'AnnualCrop': 0, 'Forest': 1, 'HerbaceousVegetation': 2, 'Highway': 3, 'Industrial': 4, 'Pasture': 5, 'PermanentCrop': 6, 'Residential': 7, 'River': 8, 'SeaLake': 9}

# %% [markdown]
# ## 4. Helper Functions
#
# Utility functions used to build the model, visualize training curves,
# summarize evaluation metrics, and preview predictions.
#
# - `compile_model` — builds a ResNet152V2 backbone (ImageNet weights) with a
#   custom dense classification head, and freezes/unfreezes backbone layers
#   as requested via `fine_tune`.
# - `plot_history` — plots training/validation accuracy and loss curves.
# - `display_results` — computes per-class precision/recall/F-score plus
#   overall accuracy and F2-score, and returns a confusion matrix.
# - `plot_predictions` — shows a grid of sample test images with predicted
#   vs. true labels.

# %%
def compile_model(cnn_base, input_shape, n_classes, optimizer, fine_tune=None):
    """Build and compile a ResNet152V2 classifier.

    Parameters
    ----------
    cnn_base : str
        Name of the backbone to use. Only 'ResNet152V2' is used in this
        notebook; the conditional structure is kept so the function stays
        consistent with the sibling notebooks for the other architectures.
    input_shape : tuple
        Shape of the input images, e.g. (64, 64, 3).
    n_classes : int
        Number of output classes.
    optimizer : keras.optimizers.Optimizer
        Optimizer instance to compile the model with.
    fine_tune : int or None
        If None, all backbone layers are frozen (only the new head trains).
        If an int, backbone layers from that index onward are unfrozen for
        end-to-end fine-tuning (0 unfreezes the entire backbone).
    """
    if cnn_base == 'ResNet152V2':
        conv_base = ResNet152V2(
            include_top=False,
            weights='imagenet',
            input_shape=input_shape,
        )
    else:
        raise ValueError(f"Unsupported cnn_base for this notebook: {cnn_base}")

    top_model = conv_base.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dropout(0.5)(top_model)

    output_layer = Dense(
        n_classes, activation='softmax', kernel_regularizer=l2(0.01)
    )(top_model)

    model = Model(inputs=conv_base.input, outputs=output_layer)

    if isinstance(fine_tune, int):
        for layer in conv_base.layers[fine_tune:]:
            layer.trainable = True
    else:
        for layer in conv_base.layers:
            layer.trainable = False

    model.compile(
        optimizer=optimizer,
        loss='categorical_crossentropy',
        metrics=['categorical_accuracy'],
    )

    return model


def plot_history(history):
    """Plot training/validation accuracy and loss curves."""
    acc = history.history['categorical_accuracy']
    val_acc = history.history['val_categorical_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(acc)
    plt.plot(val_acc)
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(loss)
    plt.plot(val_loss)
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')

    plt.show()


def display_results(y_true, y_preds, class_labels):
    """Print accuracy/F2-score and return per-class metrics + confusion matrix."""
    results = pd.DataFrame(
        precision_recall_fscore_support(y_true, y_preds),
        columns=class_labels,
    ).T
    results.rename(
        columns={0: 'Precision', 1: 'Recall', 2: 'F-Score', 3: 'Support'},
        inplace=True,
    )

    conf_mat = pd.DataFrame(
        confusion_matrix(y_true, y_preds),
        columns=class_labels,
        index=class_labels,
    )

    f2 = fbeta_score(y_true, y_preds, beta=2, average='micro')
    macro_f1 = f1_score(y_true, y_preds, average='macro')
    accuracy = accuracy_score(y_true, y_preds)
    print(f"Accuracy: {accuracy}")
    print(f"Macro F1 Score: {macro_f1}")
    print(f"Global F2 Score: {f2}")

    return results, conf_mat


def plot_predictions(y_true, y_preds, test_generator, class_indices):
    """Show a grid of test images with predicted vs. true class labels."""
    fig = plt.figure(figsize=(20, 10))
    for i, idx in enumerate(
        np.random.choice(test_generator.samples, size=20, replace=False)
    ):
        ax = fig.add_subplot(4, 5, i + 1, xticks=[], yticks=[])
        image = np.squeeze(test_generator[idx])
        # Shifts the ResNet [-1, 1] pixel range back to a normal [0, 1] range for Matplotlib
        image_for_plot = (image + 1.0) / 2.0
        plt.imshow(image_for_plot)
        pred_idx = np.argmax(y_preds[idx])
        true_idx = y_true[idx]

        plt.tight_layout()
        ax.set_title(
            "{}\n({})".format(class_indices[pred_idx], class_indices[true_idx]),
            color=("green" if pred_idx == true_idx else "red"),
        )

# %% [markdown]
# ## 5. Training Configuration
#
# Define per-stage file paths for checkpoints and CSV logs. Each training
# stage saves its own best-weights checkpoint and a CSV log of all completed
# epochs. On restart, the notebook reads the log to determine where to
# resume from — no manual editing required.

# %%
N_STEPS = len(train_generator)      # = ceil(samples / batch_size)
N_VAL_STEPS = len(test_generator)   # = ceil(samples / batch_size)

# --- File paths for local resilient training ---

# Stage 1: Head-only training
HEAD_EPOCHS = 50
HEAD_CHECKPOINT = os.path.join(SAVE_DIR, 'resnet152v2_head.weights.best.keras')
HEAD_LOG = os.path.join(SAVE_DIR, 'resnet152v2_head_log.csv')
HEAD_DONE_FLAG = os.path.join(SAVE_DIR, '.resnet152v2_head_done')

# Stage 2: Full fine-tuning
FINETUNE_EPOCHS = 100
FINETUNE_CHECKPOINT = os.path.join(SAVE_DIR, 'resnet152v2_finetune.weights.best.keras')
FINETUNE_LOG = os.path.join(SAVE_DIR, 'resnet152v2_finetune_log.csv')
FINETUNE_DONE_FLAG = os.path.join(SAVE_DIR, '.resnet152v2_finetune_done')

print(f"Training steps/epoch: {N_STEPS}, Validation steps/epoch: {N_VAL_STEPS}")

# Mild targeted class balancing
TARGET_CLASS_WEIGHTS = {
    'Highway': 1.35,
    'River': 1.35,
    'HerbaceousVegetation': 1.20,
    'Pasture': 1.20,
    'PermanentCrop': 1.20,
}

class_weight = {
    idx: TARGET_CLASS_WEIGHTS.get(class_name, 1.0)
    for class_name, idx in train_generator.class_indices.items()
}
# Out:
# Training steps/epoch: 338, Validation steps/epoch: 85

# %% [markdown]
# ## 6. ResNet152V2 Model
#
# Training is done in two stages, a common transfer-learning recipe:
#
# 1. **Head-only training** — the ResNet152V2 backbone (pretrained on
#    ImageNet) is frozen, and only the new dense classification head is
#    trained with a relatively high learning rate.
# 2. **End-to-end fine-tuning** — the entire network is unfrozen and trained
#    further at a much lower learning rate, using the best head-only weights
#    as the starting point.

# %% [markdown]
# ### 6.1 Build the model

# %%
resnet152V2_model = compile_model(
    'ResNet152V2', INPUT_SHAPE, NUM_CLASSES, Adam(learning_rate=1e-2), fine_tune=None
)
resnet152V2_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 70, 70, 3) │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 32, 32,    │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 34, 34,    │          0 │ conv1_conv[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 16, 16,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 16, 16,    │        256 │ pool1_pool[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_preac… │ (None, 16, 16,    │          0 │ conv2_block1_pre… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 16, 16,    │      4,096 │ conv2_block1_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 16, 16,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 16, 16,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_pad  │ (None, 18, 18,    │          0 │ conv2_block1_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 16, 16,    │     36,864 │ conv2_block1_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 16, 16,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 16, 16,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 16, 16,    │     16,640 │ conv2_block1_pre… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 16, 16,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 16, 16,    │          0 │ conv2_block1_0_c… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 16, 16,    │      1,024 │ conv2_block1_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_preac… │ (None, 16, 16,    │          0 │ conv2_block2_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 16, 16,    │     16,384 │ conv2_block2_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 16, 16,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 16, 16,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_pad  │ (None, 18, 18,    │          0 │ conv2_block2_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 16, 16,    │     36,864 │ conv2_block2_2_p… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 16, 16,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 16, 16,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 16, 16,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 16, 16,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 16, 16,    │      1,024 │ conv2_block2_out… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_preac… │ (None, 16, 16,    │          0 │ conv2_block3_pre… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 16, 16,    │     16,384 │ conv2_block3_pre… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 16, 16,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 16, 16,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_pad  │ (None, 18, 18,    │          0 │ conv2_block3_1_r… │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 8, 8, 64)  │     36,864 │ conv2_block3_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 8, 8, 64)  │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 8, 8, 64)  │          0 │ conv2_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 8, 256) │          0 │ conv2_block2_out… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 8, 8, 256) │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 8, 8, 256) │          0 │ max_pooling2d[0]… │
# │ (Add)               │                   │            │ conv2_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_preac… │ (None, 8, 8, 256) │      1,024 │ conv2_block3_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_preac… │ (None, 8, 8, 256) │          0 │ conv3_block1_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 8, 8, 128) │     32,768 │ conv3_block1_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 8, 8, 128) │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 8, 8, 128) │          0 │ conv3_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_pad  │ (None, 10, 10,    │          0 │ conv3_block1_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 8, 8, 128) │    147,456 │ conv3_block1_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 8, 8, 128) │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 8, 8, 128) │          0 │ conv3_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 8, 8, 512) │    131,584 │ conv3_block1_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 8, 8, 512) │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 8, 8, 512) │          0 │ conv3_block1_0_c… │
# │ (Add)               │                   │            │ conv3_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_preac… │ (None, 8, 8, 512) │      2,048 │ conv3_block1_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_preac… │ (None, 8, 8, 512) │          0 │ conv3_block2_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 8, 8, 128) │     65,536 │ conv3_block2_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 8, 8, 128) │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 8, 8, 128) │          0 │ conv3_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_pad  │ (None, 10, 10,    │          0 │ conv3_block2_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 8, 8, 128) │    147,456 │ conv3_block2_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 8, 8, 128) │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 8, 8, 128) │          0 │ conv3_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 8, 8, 512) │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 8, 8, 512) │          0 │ conv3_block1_out… │
# │ (Add)               │                   │            │ conv3_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_preac… │ (None, 8, 8, 512) │      2,048 │ conv3_block2_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_preac… │ (None, 8, 8, 512) │          0 │ conv3_block3_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 8, 8, 128) │     65,536 │ conv3_block3_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 8, 8, 128) │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 8, 8, 128) │          0 │ conv3_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_pad  │ (None, 10, 10,    │          0 │ conv3_block3_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 8, 8, 128) │    147,456 │ conv3_block3_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 8, 8, 128) │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 8, 8, 128) │          0 │ conv3_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 8, 8, 512) │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 8, 8, 512) │          0 │ conv3_block2_out… │
# │ (Add)               │                   │            │ conv3_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_preac… │ (None, 8, 8, 512) │      2,048 │ conv3_block3_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_preac… │ (None, 8, 8, 512) │          0 │ conv3_block4_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 8, 8, 128) │     65,536 │ conv3_block4_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 8, 8, 128) │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 8, 8, 128) │          0 │ conv3_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_pad  │ (None, 10, 10,    │          0 │ conv3_block4_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 8, 8, 128) │    147,456 │ conv3_block4_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 8, 8, 128) │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 8, 8, 128) │          0 │ conv3_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 8, 8, 512) │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 8, 8, 512) │          0 │ conv3_block3_out… │
# │ (Add)               │                   │            │ conv3_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_preac… │ (None, 8, 8, 512) │      2,048 │ conv3_block4_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_preac… │ (None, 8, 8, 512) │          0 │ conv3_block5_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_conv │ (None, 8, 8, 128) │     65,536 │ conv3_block5_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_bn   │ (None, 8, 8, 128) │        512 │ conv3_block5_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_1_relu │ (None, 8, 8, 128) │          0 │ conv3_block5_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_pad  │ (None, 10, 10,    │          0 │ conv3_block5_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_conv │ (None, 8, 8, 128) │    147,456 │ conv3_block5_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_bn   │ (None, 8, 8, 128) │        512 │ conv3_block5_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_2_relu │ (None, 8, 8, 128) │          0 │ conv3_block5_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_3_conv │ (None, 8, 8, 512) │     66,048 │ conv3_block5_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block5_out    │ (None, 8, 8, 512) │          0 │ conv3_block4_out… │
# │ (Add)               │                   │            │ conv3_block5_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_preac… │ (None, 8, 8, 512) │      2,048 │ conv3_block5_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_preac… │ (None, 8, 8, 512) │          0 │ conv3_block6_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_conv │ (None, 8, 8, 128) │     65,536 │ conv3_block6_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_bn   │ (None, 8, 8, 128) │        512 │ conv3_block6_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_1_relu │ (None, 8, 8, 128) │          0 │ conv3_block6_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_pad  │ (None, 10, 10,    │          0 │ conv3_block6_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_conv │ (None, 8, 8, 128) │    147,456 │ conv3_block6_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_bn   │ (None, 8, 8, 128) │        512 │ conv3_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_2_relu │ (None, 8, 8, 128) │          0 │ conv3_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_3_conv │ (None, 8, 8, 512) │     66,048 │ conv3_block6_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block6_out    │ (None, 8, 8, 512) │          0 │ conv3_block5_out… │
# │ (Add)               │                   │            │ conv3_block6_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_preac… │ (None, 8, 8, 512) │      2,048 │ conv3_block6_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_preac… │ (None, 8, 8, 512) │          0 │ conv3_block7_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_conv │ (None, 8, 8, 128) │     65,536 │ conv3_block7_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_bn   │ (None, 8, 8, 128) │        512 │ conv3_block7_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_1_relu │ (None, 8, 8, 128) │          0 │ conv3_block7_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_pad  │ (None, 10, 10,    │          0 │ conv3_block7_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_conv │ (None, 8, 8, 128) │    147,456 │ conv3_block7_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_bn   │ (None, 8, 8, 128) │        512 │ conv3_block7_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_2_relu │ (None, 8, 8, 128) │          0 │ conv3_block7_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_3_conv │ (None, 8, 8, 512) │     66,048 │ conv3_block7_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block7_out    │ (None, 8, 8, 512) │          0 │ conv3_block6_out… │
# │ (Add)               │                   │            │ conv3_block7_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_preac… │ (None, 8, 8, 512) │      2,048 │ conv3_block7_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_preac… │ (None, 8, 8, 512) │          0 │ conv3_block8_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_conv │ (None, 8, 8, 128) │     65,536 │ conv3_block8_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_bn   │ (None, 8, 8, 128) │        512 │ conv3_block8_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_1_relu │ (None, 8, 8, 128) │          0 │ conv3_block8_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_pad  │ (None, 10, 10,    │          0 │ conv3_block8_1_r… │
# │ (ZeroPadding2D)     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_conv │ (None, 4, 4, 128) │    147,456 │ conv3_block8_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_bn   │ (None, 4, 4, 128) │        512 │ conv3_block8_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_2_relu │ (None, 4, 4, 128) │          0 │ conv3_block8_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 4, 4, 512) │          0 │ conv3_block7_out… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_3_conv │ (None, 4, 4, 512) │     66,048 │ conv3_block8_2_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block8_out    │ (None, 4, 4, 512) │          0 │ max_pooling2d_1[… │
# │ (Add)               │                   │            │ conv3_block8_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_preac… │ (None, 4, 4, 512) │      2,048 │ conv3_block8_out… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_preac… │ (None, 4, 4, 512) │          0 │ conv4_block1_pre… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 4, 4, 256) │    131,072 │ conv4_block1_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block1_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block1_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 4, 4,      │    525,312 │ conv4_block1_pre… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 4, 4,      │          0 │ conv4_block1_0_c… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 4, 4,      │      4,096 │ conv4_block1_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_preac… │ (None, 4, 4,      │          0 │ conv4_block2_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block2_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block2_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block2_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 4, 4,      │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 4, 4,      │      4,096 │ conv4_block2_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_preac… │ (None, 4, 4,      │          0 │ conv4_block3_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block3_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block3_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block3_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 4, 4,      │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 4, 4,      │      4,096 │ conv4_block3_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_preac… │ (None, 4, 4,      │          0 │ conv4_block4_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block4_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block4_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block4_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block4_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block4_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 4, 4,      │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 4, 4,      │      4,096 │ conv4_block4_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_preac… │ (None, 4, 4,      │          0 │ conv4_block5_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block5_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block5_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block5_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block5_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block5_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 4, 4,      │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 4, 4,      │      4,096 │ conv4_block5_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_preac… │ (None, 4, 4,      │          0 │ conv4_block6_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block6_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block6_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block6_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block6_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block6_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 4, 4,      │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 4, 4,      │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_preac… │ (None, 4, 4,      │      4,096 │ conv4_block6_out… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_preac… │ (None, 4, 4,      │          0 │ conv4_block7_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_conv │ (None, 4, 4, 256) │    262,144 │ conv4_block7_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block7_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_1_relu │ (None, 4, 4, 256) │          0 │ conv4_block7_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_2_pad  │ (None, 6, 6, 256) │          0 │ conv4_block7_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_2_conv │ (None, 4, 4, 256) │    589,824 │ conv4_block7_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_2_bn   │ (None, 4, 4, 256) │      1,024 │ conv4_block7_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block7_2_relu │ (None, 4, 4, 256) │          0 │ conv4_block7_2_b… │
# │ (Activation)        │                   │            │                   │
# ...
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block34_1_re… │ (None, 4, 4, 256) │          0 │ conv4_block34_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block34_2_pad │ (None, 6, 6, 256) │          0 │ conv4_block34_1_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block34_2_co… │ (None, 4, 4, 256) │    589,824 │ conv4_block34_2_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block34_2_bn  │ (None, 4, 4, 256) │      1,024 │ conv4_block34_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block34_2_re… │ (None, 4, 4, 256) │          0 │ conv4_block34_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block34_3_co… │ (None, 4, 4,      │    263,168 │ conv4_block34_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block34_out   │ (None, 4, 4,      │          0 │ conv4_block33_ou… │
# │ (Add)               │ 1024)             │            │ conv4_block34_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_prea… │ (None, 4, 4,      │      4,096 │ conv4_block34_ou… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_prea… │ (None, 4, 4,      │          0 │ conv4_block35_pr… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_1_co… │ (None, 4, 4, 256) │    262,144 │ conv4_block35_pr… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_1_bn  │ (None, 4, 4, 256) │      1,024 │ conv4_block35_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_1_re… │ (None, 4, 4, 256) │          0 │ conv4_block35_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_2_pad │ (None, 6, 6, 256) │          0 │ conv4_block35_1_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_2_co… │ (None, 4, 4, 256) │    589,824 │ conv4_block35_2_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_2_bn  │ (None, 4, 4, 256) │      1,024 │ conv4_block35_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_2_re… │ (None, 4, 4, 256) │          0 │ conv4_block35_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_3_co… │ (None, 4, 4,      │    263,168 │ conv4_block35_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block35_out   │ (None, 4, 4,      │          0 │ conv4_block34_ou… │
# │ (Add)               │ 1024)             │            │ conv4_block35_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_prea… │ (None, 4, 4,      │      4,096 │ conv4_block35_ou… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_prea… │ (None, 4, 4,      │          0 │ conv4_block36_pr… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_1_co… │ (None, 4, 4, 256) │    262,144 │ conv4_block36_pr… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_1_bn  │ (None, 4, 4, 256) │      1,024 │ conv4_block36_1_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_1_re… │ (None, 4, 4, 256) │          0 │ conv4_block36_1_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_2_pad │ (None, 6, 6, 256) │          0 │ conv4_block36_1_… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_2_co… │ (None, 2, 2, 256) │    589,824 │ conv4_block36_2_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_2_bn  │ (None, 2, 2, 256) │      1,024 │ conv4_block36_2_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_2_re… │ (None, 2, 2, 256) │          0 │ conv4_block36_2_… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 2, 2,      │          0 │ conv4_block35_ou… │
# │ (MaxPooling2D)      │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_3_co… │ (None, 2, 2,      │    263,168 │ conv4_block36_2_… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block36_out   │ (None, 2, 2,      │          0 │ max_pooling2d_2[… │
# │ (Add)               │ 1024)             │            │ conv4_block36_3_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_preac… │ (None, 2, 2,      │      4,096 │ conv4_block36_ou… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_preac… │ (None, 2, 2,      │          0 │ conv5_block1_pre… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 2, 2, 512) │    524,288 │ conv5_block1_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 2, 2, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_pad  │ (None, 4, 4, 512) │          0 │ conv5_block1_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 2, 2, 512) │  2,359,296 │ conv5_block1_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 2, 2, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 2, 2,      │  2,099,200 │ conv5_block1_pre… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 2, 2,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 2, 2,      │          0 │ conv5_block1_0_c… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_preac… │ (None, 2, 2,      │      8,192 │ conv5_block1_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_preac… │ (None, 2, 2,      │          0 │ conv5_block2_pre… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 2, 2, 512) │  1,048,576 │ conv5_block2_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 2, 2, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_pad  │ (None, 4, 4, 512) │          0 │ conv5_block2_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 2, 2, 512) │  2,359,296 │ conv5_block2_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 2, 2, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 2, 2,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 2, 2,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_preac… │ (None, 2, 2,      │      8,192 │ conv5_block2_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_preac… │ (None, 2, 2,      │          0 │ conv5_block3_pre… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 2, 2, 512) │  1,048,576 │ conv5_block3_pre… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 2, 2, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_pad  │ (None, 4, 4, 512) │          0 │ conv5_block3_1_r… │
# │ (ZeroPadding2D)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 2, 2, 512) │  2,359,296 │ conv5_block3_2_p… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 2, 2, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 2, 2, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 2, 2,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 2, 2,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ post_bn             │ (None, 2, 2,      │      8,192 │ conv5_block3_out… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ post_relu           │ (None, 2, 2,      │          0 │ post_bn[0][0]     │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 2048)      │          0 │ post_relu[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 2048)      │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10)        │     20,490 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 58,352,138 (222.60 MB)
#  Trainable params: 20,490 (80.04 KB)
#  Non-trainable params: 58,331,648 (222.52 MB)

# %% [markdown]
# ### 6.2 Stage 1 — Head-only training
#
# Train only the classification head (backbone frozen). Training
# automatically resumes from the last completed epoch if the runtime
# restarts.

# %%
# --- Stage 1: Head-only training (frozen backbone) ---
if os.path.exists(HEAD_DONE_FLAG):
    print(">> Stage 1 (head-only training) already completed. Skipping.")
    resnet152V2_model.load_weights(HEAD_CHECKPOINT)
else:
    head_resume_epoch = 0

    # Check for existing progress to resume from
    if os.path.exists(HEAD_LOG) and os.path.exists(HEAD_CHECKPOINT):
        try:
            df = pd.read_csv(HEAD_LOG)
            if not df.empty:
                head_resume_epoch = len(df)
                resnet152V2_model.load_weights(HEAD_CHECKPOINT)
                print(f">> Resuming head-only training from epoch {head_resume_epoch + 1}/{HEAD_EPOCHS}")
        except Exception as e:
            print(f"Error reading log ({e}). Starting from scratch.")
            head_resume_epoch = 0

    if head_resume_epoch == 0:
        print(">> Starting head-only training from scratch.")

    head_callbacks = [
        EarlyStopping(
            monitor='val_categorical_accuracy', patience=10,
            restore_best_weights=True, mode='max',
        ),
        ModelCheckpoint(
            filepath=HEAD_CHECKPOINT, monitor='val_categorical_accuracy',
            save_best_only=True, verbose=1,
        ),
        CSVLogger(HEAD_LOG, append=(head_resume_epoch > 0)),
    ]

    resnet152V2_history = resnet152V2_model.fit(
        train_generator,
        steps_per_epoch=N_STEPS,
        epochs=HEAD_EPOCHS,
        initial_epoch=head_resume_epoch,
        callbacks=head_callbacks,
        class_weight=class_weight,
        validation_data=test_generator,
        validation_steps=N_VAL_STEPS,
    )

    # Mark stage as complete
    with open(HEAD_DONE_FLAG, 'w') as f:
        f.write('done')
    print(">> Stage 1 (head-only training) complete.")
# Out:
# >> Starting head-only training from scratch.
# Epoch 1/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - categorical_accuracy: 0.5934 - loss: 2.2486
# Epoch 1: val_categorical_accuracy improved from None to 0.74519, saving model to EuroSAT_Models/resnet152v2_head.weights.best.keras
#
# Epoch 1: finished saving model to EuroSAT_Models/resnet152v2_head.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 109s 243ms/step - categorical_accuracy: 0.6237 - loss: 2.2788 - val_categorical_accuracy: 0.7452 - val_loss: 1.6645
# Epoch 2/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_accuracy: 0.6397 - loss: 2.2746
# Epoch 2: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 54s 159ms/step - categorical_accuracy: 0.6411 - loss: 2.2549 - val_categorical_accuracy: 0.7265 - val_loss: 1.7171
# Epoch 3/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_accuracy: 0.6376 - loss: 2.3058
# Epoch 3: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 53s 157ms/step - categorical_accuracy: 0.6340 - loss: 2.3149 - val_categorical_accuracy: 0.7315 - val_loss: 1.6967
# Epoch 4/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - categorical_accuracy: 0.6359 - loss: 2.3517
# Epoch 4: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 53s 158ms/step - categorical_accuracy: 0.6357 - loss: 2.3407 - val_categorical_accuracy: 0.7185 - val_loss: 1.7831
# Epoch 5/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - categorical_accuracy: 0.6291 - loss: 2.4377
# Epoch 5: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 52s 155ms/step - categorical_accuracy: 0.6313 - loss: 2.4208 - val_categorical_accuracy: 0.7224 - val_loss: 1.8971
# Epoch 6/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - categorical_accuracy: 0.6343 - loss: 2.4193
# Epoch 6: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 54s 159ms/step - categorical_accuracy: 0.6317 - loss: 2.4190 - val_categorical_accuracy: 0.7252 - val_loss: 1.7894
# Epoch 7/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_accuracy: 0.6283 - loss: 2.4062
# Epoch 7: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 81s 156ms/step - categorical_accuracy: 0.6280 - loss: 2.4250 - val_categorical_accuracy: 0.7413 - val_loss: 1.7158
# Epoch 8/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_accuracy: 0.6379 - loss: 2.3229
# Epoch 8: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 82s 157ms/step - categorical_accuracy: 0.6370 - loss: 2.3252 - val_categorical_accuracy: 0.7265 - val_loss: 1.7497
# Epoch 9/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - categorical_accuracy: 0.6342 - loss: 2.3956
# Epoch 9: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 55s 161ms/step - categorical_accuracy: 0.6346 - loss: 2.3632 - val_categorical_accuracy: 0.7293 - val_loss: 1.6308
# Epoch 10/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - categorical_accuracy: 0.6361 - loss: 2.3120
# Epoch 10: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 53s 158ms/step - categorical_accuracy: 0.6387 - loss: 2.3558 - val_categorical_accuracy: 0.7206 - val_loss: 1.7604
# Epoch 11/50
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - categorical_accuracy: 0.6384 - loss: 2.4648
# Epoch 11: val_categorical_accuracy did not improve from 0.74519
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 52s 155ms/step - categorical_accuracy: 0.6354 - loss: 2.4539 - val_categorical_accuracy: 0.7315 - val_loss: 1.6767
# >> Stage 1 (head-only training) complete.

# %% [markdown]
# ### 6.3 Stage 2 — End-to-end fine-tuning
#
# Unfreeze the entire backbone and continue training at a lower learning
# rate. Automatically resumes from the last completed epoch if the runtime
# restarts.

# %%
# --- Stage 2: End-to-end fine-tuning (all layers unfrozen) ---
from tensorflow.keras.optimizers.schedules import CosineDecayRestarts
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, CSVLogger

initial_learning_rate = 1e-4
lr_schedule = CosineDecayRestarts(
    initial_learning_rate=initial_learning_rate,
    first_decay_steps=10 * N_STEPS,
    t_mul=2.0,
    m_mul=0.9,
    alpha=0.01,
)

# This perfectly unfreezes the model using YOUR custom function!
resnet152V2_model = compile_model(
    'ResNet152V2', INPUT_SHAPE, NUM_CLASSES, Adam(learning_rate=lr_schedule), fine_tune=0
)

if os.path.exists(FINETUNE_DONE_FLAG):
    print(">> Stage 2 (fine-tuning) already completed. Loading best weights.")
    resnet152V2_model.load_weights(FINETUNE_CHECKPOINT)
else:
    finetune_resume_epoch = 0

    # Check for existing progress to resume from
    if os.path.exists(FINETUNE_LOG) and os.path.exists(FINETUNE_CHECKPOINT):
        try:
            df = pd.read_csv(FINETUNE_LOG)
            if not df.empty:
                finetune_resume_epoch = len(df)
                resnet152V2_model.load_weights(FINETUNE_CHECKPOINT)
                print(f">> Resuming fine-tuning from epoch {finetune_resume_epoch + 1}/{FINETUNE_EPOCHS}")
        except Exception as e:
            print(f"Error reading log ({e}). Starting fine-tuning from head weights.")
            finetune_resume_epoch = 0

    if finetune_resume_epoch == 0:
        # Start fine-tuning from the best head-only weights
        resnet152V2_model.load_weights(HEAD_CHECKPOINT)
        print(">> Starting fine-tuning from best head-only weights.")

    # THE PLAN A UPGRADES (Inside your auto-resume list!)
    finetune_callbacks = [
        EarlyStopping(
            monitor='val_loss',         # Monitor Loss instead of Accuracy
            patience=25,                # Extended to 25 to survive Cosine Restarts
            restore_best_weights=True,
            mode='min',
        ),
        ModelCheckpoint(
            filepath=FINETUNE_CHECKPOINT, # Keeps your file naming system intact!
            monitor='val_loss',
            save_best_only=True,
            verbose=1,
            mode='min'
        ),
        CSVLogger(FINETUNE_LOG, append=(finetune_resume_epoch > 0)),
    ]

    resnet152V2_history = resnet152V2_model.fit(
        train_generator,
        steps_per_epoch=N_STEPS,
        epochs=FINETUNE_EPOCHS,
        initial_epoch=finetune_resume_epoch,
        callbacks=finetune_callbacks,
        class_weight=class_weight,
        validation_data=test_generator,
        validation_steps=N_VAL_STEPS,
    )

    # Mark stage as complete
    with open(FINETUNE_DONE_FLAG, 'w') as f:
        f.write('done')
    print(">> Stage 2 (fine-tuning) complete.")
# Out:
# >> Starting fine-tuning from best head-only weights.
# Epoch 1/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step - categorical_accuracy: 0.6702 - loss: 2.1881
# Epoch 1: val_loss improved from None to 0.86708, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 1: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 279s 441ms/step - categorical_accuracy: 0.7890 - loss: 1.4852 - val_categorical_accuracy: 0.9137 - val_loss: 0.8671
# Epoch 2/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - categorical_accuracy: 0.8946 - loss: 0.9515
# Epoch 2: val_loss improved from 0.86708 to 0.81178, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 2: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 91s 268ms/step - categorical_accuracy: 0.9026 - loss: 0.9066 - val_categorical_accuracy: 0.9104 - val_loss: 0.8118
# Epoch 3/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - categorical_accuracy: 0.9240 - loss: 0.7888
# Epoch 3: val_loss improved from 0.81178 to 0.69415, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 3: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 104s 307ms/step - categorical_accuracy: 0.9256 - loss: 0.7645 - val_categorical_accuracy: 0.9165 - val_loss: 0.6942
# Epoch 4/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - categorical_accuracy: 0.9374 - loss: 0.6773
# Epoch 4: val_loss improved from 0.69415 to 0.59478, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 4: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 104s 309ms/step - categorical_accuracy: 0.9388 - loss: 0.6609 - val_categorical_accuracy: 0.9417 - val_loss: 0.5948
# Epoch 5/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - categorical_accuracy: 0.9436 - loss: 0.6036
# Epoch 5: val_loss improved from 0.59478 to 0.56976, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 5: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 127s 265ms/step - categorical_accuracy: 0.9458 - loss: 0.5828 - val_categorical_accuracy: 0.9372 - val_loss: 0.5698
# Epoch 6/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step - categorical_accuracy: 0.9522 - loss: 0.5319
# Epoch 6: val_loss improved from 0.56976 to 0.48319, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 6: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 113s 333ms/step - categorical_accuracy: 0.9537 - loss: 0.5214 - val_categorical_accuracy: 0.9541 - val_loss: 0.4832
# Epoch 7/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9590 - loss: 0.4856
# Epoch 7: val_loss improved from 0.48319 to 0.45722, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 7: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 117s 345ms/step - categorical_accuracy: 0.9582 - loss: 0.4785 - val_categorical_accuracy: 0.9537 - val_loss: 0.4572
# Epoch 8/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9639 - loss: 0.4469
# Epoch 8: val_loss improved from 0.45722 to 0.44615, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 8: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 122s 360ms/step - categorical_accuracy: 0.9628 - loss: 0.4495 - val_categorical_accuracy: 0.9539 - val_loss: 0.4462
# Epoch 9/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9688 - loss: 0.4261
# Epoch 9: val_loss did not improve from 0.44615
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 234ms/step - categorical_accuracy: 0.9677 - loss: 0.4249 - val_categorical_accuracy: 0.9507 - val_loss: 0.4523
# Epoch 10/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9678 - loss: 0.4196
# Epoch 10: val_loss did not improve from 0.44615
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 234ms/step - categorical_accuracy: 0.9665 - loss: 0.4238 - val_categorical_accuracy: 0.9509 - val_loss: 0.4471
# Epoch 11/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9497 - loss: 0.4627
# Epoch 11: val_loss did not improve from 0.44615
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 236ms/step - categorical_accuracy: 0.9432 - loss: 0.4727 - val_categorical_accuracy: 0.9278 - val_loss: 0.4703
# Epoch 12/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9498 - loss: 0.4088
# Epoch 12: val_loss improved from 0.44615 to 0.34612, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 12: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 108s 312ms/step - categorical_accuracy: 0.9486 - loss: 0.4001 - val_categorical_accuracy: 0.9537 - val_loss: 0.3461
# Epoch 13/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9567 - loss: 0.3396
# Epoch 13: val_loss improved from 0.34612 to 0.33854, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 13: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 95s 280ms/step - categorical_accuracy: 0.9569 - loss: 0.3300 - val_categorical_accuracy: 0.9415 - val_loss: 0.3385
# Epoch 14/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - categorical_accuracy: 0.9605 - loss: 0.2915
# Epoch 14: val_loss did not improve from 0.33854
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 236ms/step - categorical_accuracy: 0.9598 - loss: 0.2857 - val_categorical_accuracy: 0.9291 - val_loss: 0.3539
# Epoch 15/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9626 - loss: 0.2584
# Epoch 15: val_loss improved from 0.33854 to 0.26861, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 15: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 328ms/step - categorical_accuracy: 0.9639 - loss: 0.2527 - val_categorical_accuracy: 0.9502 - val_loss: 0.2686
# Epoch 16/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9663 - loss: 0.2251
# Epoch 16: val_loss improved from 0.26861 to 0.23416, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 16: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 107s 317ms/step - categorical_accuracy: 0.9653 - loss: 0.2254 - val_categorical_accuracy: 0.9537 - val_loss: 0.2342
# Epoch 17/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9690 - loss: 0.2048
# Epoch 17: val_loss did not improve from 0.23416
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - categorical_accuracy: 0.9688 - loss: 0.2013 - val_categorical_accuracy: 0.9519 - val_loss: 0.2386
# Epoch 18/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9736 - loss: 0.1795
# Epoch 18: val_loss improved from 0.23416 to 0.20301, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 18: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 100s 294ms/step - categorical_accuracy: 0.9741 - loss: 0.1782 - val_categorical_accuracy: 0.9567 - val_loss: 0.2030
# Epoch 19/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9757 - loss: 0.1617
# Epoch 19: val_loss did not improve from 0.20301
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - categorical_accuracy: 0.9756 - loss: 0.1614 - val_categorical_accuracy: 0.9543 - val_loss: 0.2192
# Epoch 20/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9783 - loss: 0.1440
# Epoch 20: val_loss did not improve from 0.20301
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 232ms/step - categorical_accuracy: 0.9773 - loss: 0.1487 - val_categorical_accuracy: 0.9554 - val_loss: 0.2042
# Epoch 21/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9801 - loss: 0.1346
# Epoch 21: val_loss improved from 0.20301 to 0.18000, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 21: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 111s 329ms/step - categorical_accuracy: 0.9794 - loss: 0.1363 - val_categorical_accuracy: 0.9631 - val_loss: 0.1800
# Epoch 22/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9818 - loss: 0.1280
# Epoch 22: val_loss improved from 0.18000 to 0.17293, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 22: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 102s 303ms/step - categorical_accuracy: 0.9814 - loss: 0.1263 - val_categorical_accuracy: 0.9650 - val_loss: 0.1729
# Epoch 23/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9848 - loss: 0.1115
# Epoch 23: val_loss did not improve from 0.17293
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 233ms/step - categorical_accuracy: 0.9842 - loss: 0.1129 - val_categorical_accuracy: 0.9517 - val_loss: 0.2256
# Epoch 24/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9872 - loss: 0.1014
# Epoch 24: val_loss improved from 0.17293 to 0.15890, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 24: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 90s 257ms/step - categorical_accuracy: 0.9874 - loss: 0.1016 - val_categorical_accuracy: 0.9672 - val_loss: 0.1589
# Epoch 25/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9863 - loss: 0.1020
# Epoch 25: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 236ms/step - categorical_accuracy: 0.9875 - loss: 0.0983 - val_categorical_accuracy: 0.9620 - val_loss: 0.1727
# Epoch 26/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9888 - loss: 0.0925
# Epoch 26: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 233ms/step - categorical_accuracy: 0.9893 - loss: 0.0911 - val_categorical_accuracy: 0.9587 - val_loss: 0.1858
# Epoch 27/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9911 - loss: 0.0838
# Epoch 27: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 233ms/step - categorical_accuracy: 0.9914 - loss: 0.0836 - val_categorical_accuracy: 0.9637 - val_loss: 0.1674
# Epoch 28/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9894 - loss: 0.0863
# Epoch 28: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 235ms/step - categorical_accuracy: 0.9901 - loss: 0.0845 - val_categorical_accuracy: 0.9593 - val_loss: 0.1844
# Epoch 29/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9903 - loss: 0.0831
# Epoch 29: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 235ms/step - categorical_accuracy: 0.9912 - loss: 0.0813 - val_categorical_accuracy: 0.9622 - val_loss: 0.1721
# Epoch 30/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9914 - loss: 0.0785
# Epoch 30: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 235ms/step - categorical_accuracy: 0.9913 - loss: 0.0790 - val_categorical_accuracy: 0.9617 - val_loss: 0.1717
# Epoch 31/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9695 - loss: 0.1580
# Epoch 31: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 81s 239ms/step - categorical_accuracy: 0.9619 - loss: 0.1844 - val_categorical_accuracy: 0.9465 - val_loss: 0.2269
# Epoch 32/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - categorical_accuracy: 0.9656 - loss: 0.1711
# Epoch 32: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - categorical_accuracy: 0.9652 - loss: 0.1655 - val_categorical_accuracy: 0.9513 - val_loss: 0.1900
# Epoch 33/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9709 - loss: 0.1426
# Epoch 33: val_loss did not improve from 0.15890
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - categorical_accuracy: 0.9706 - loss: 0.1435 - val_categorical_accuracy: 0.9431 - val_loss: 0.2149
# Epoch 34/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9732 - loss: 0.1308
# Epoch 34: val_loss improved from 0.15890 to 0.15396, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 34: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 90s 266ms/step - categorical_accuracy: 0.9721 - loss: 0.1342 - val_categorical_accuracy: 0.9589 - val_loss: 0.1540
# Epoch 35/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9734 - loss: 0.1230
# Epoch 35: val_loss did not improve from 0.15396
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 133s 239ms/step - categorical_accuracy: 0.9736 - loss: 0.1242 - val_categorical_accuracy: 0.9272 - val_loss: 0.2491
# Epoch 36/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9754 - loss: 0.1174
# Epoch 36: val_loss did not improve from 0.15396
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 81s 238ms/step - categorical_accuracy: 0.9766 - loss: 0.1116 - val_categorical_accuracy: 0.9481 - val_loss: 0.2009
# Epoch 37/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9761 - loss: 0.1168
# Epoch 37: val_loss did not improve from 0.15396
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 81s 240ms/step - categorical_accuracy: 0.9765 - loss: 0.1102 - val_categorical_accuracy: 0.9609 - val_loss: 0.1540
# Epoch 38/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9803 - loss: 0.0960
# Epoch 38: val_loss did not improve from 0.15396
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 235ms/step - categorical_accuracy: 0.9795 - loss: 0.1000 - val_categorical_accuracy: 0.9359 - val_loss: 0.2240
# Epoch 39/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - categorical_accuracy: 0.9800 - loss: 0.0991
# Epoch 39: val_loss did not improve from 0.15396
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 236ms/step - categorical_accuracy: 0.9799 - loss: 0.1001 - val_categorical_accuracy: 0.9470 - val_loss: 0.1951
# Epoch 40/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9818 - loss: 0.0883
# Epoch 40: val_loss improved from 0.15396 to 0.14796, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 40: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 102s 301ms/step - categorical_accuracy: 0.9821 - loss: 0.0890 - val_categorical_accuracy: 0.9596 - val_loss: 0.1480
# Epoch 41/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9822 - loss: 0.0854
# Epoch 41: val_loss did not improve from 0.14796
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 121s 238ms/step - categorical_accuracy: 0.9824 - loss: 0.0874 - val_categorical_accuracy: 0.9602 - val_loss: 0.1561
# Epoch 42/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9818 - loss: 0.0851
# Epoch 42: val_loss did not improve from 0.14796
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 234ms/step - categorical_accuracy: 0.9813 - loss: 0.0845 - val_categorical_accuracy: 0.9402 - val_loss: 0.2107
# Epoch 43/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9842 - loss: 0.0745
# Epoch 43: val_loss did not improve from 0.14796
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 82s 235ms/step - categorical_accuracy: 0.9832 - loss: 0.0809 - val_categorical_accuracy: 0.9376 - val_loss: 0.2132
# Epoch 44/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - categorical_accuracy: 0.9849 - loss: 0.0733
# Epoch 44: val_loss did not improve from 0.14796
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 233ms/step - categorical_accuracy: 0.9843 - loss: 0.0736 - val_categorical_accuracy: 0.9504 - val_loss: 0.1698
# Epoch 45/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9868 - loss: 0.0688
# Epoch 45: val_loss did not improve from 0.14796
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - categorical_accuracy: 0.9868 - loss: 0.0672 - val_categorical_accuracy: 0.9326 - val_loss: 0.2537
# Epoch 46/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9852 - loss: 0.0710
# Epoch 46: val_loss improved from 0.14796 to 0.13796, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 46: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 136s 403ms/step - categorical_accuracy: 0.9856 - loss: 0.0689 - val_categorical_accuracy: 0.9619 - val_loss: 0.1380
# Epoch 47/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9879 - loss: 0.0595
# Epoch 47: val_loss did not improve from 0.13796
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 234ms/step - categorical_accuracy: 0.9872 - loss: 0.0619 - val_categorical_accuracy: 0.9606 - val_loss: 0.1499
# Epoch 48/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9890 - loss: 0.0559
# Epoch 48: val_loss improved from 0.13796 to 0.13284, saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
#
# Epoch 48: finished saving model to EuroSAT_Models/resnet152v2_finetune.weights.best.keras
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 121s 359ms/step - categorical_accuracy: 0.9882 - loss: 0.0569 - val_categorical_accuracy: 0.9659 - val_loss: 0.1328
# Epoch 49/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - categorical_accuracy: 0.9911 - loss: 0.0470
# Epoch 49: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 237ms/step - categorical_accuracy: 0.9911 - loss: 0.0478 - val_categorical_accuracy: 0.9611 - val_loss: 0.1564
# Epoch 50/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9911 - loss: 0.0475
# Epoch 50: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 236ms/step - categorical_accuracy: 0.9908 - loss: 0.0485 - val_categorical_accuracy: 0.9615 - val_loss: 0.1545
# Epoch 51/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9918 - loss: 0.0472
# Epoch 51: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 82s 236ms/step - categorical_accuracy: 0.9912 - loss: 0.0480 - val_categorical_accuracy: 0.9622 - val_loss: 0.1504
# Epoch 52/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9908 - loss: 0.0468
# Epoch 52: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 83s 239ms/step - categorical_accuracy: 0.9911 - loss: 0.0471 - val_categorical_accuracy: 0.9617 - val_loss: 0.1477
# Epoch 53/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - categorical_accuracy: 0.9941 - loss: 0.0388
# Epoch 53: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 81s 239ms/step - categorical_accuracy: 0.9932 - loss: 0.0422 - val_categorical_accuracy: 0.9469 - val_loss: 0.2034
# Epoch 54/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9950 - loss: 0.0344
# Epoch 54: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 80s 238ms/step - categorical_accuracy: 0.9946 - loss: 0.0349 - val_categorical_accuracy: 0.9635 - val_loss: 0.1456
# Epoch 55/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9937 - loss: 0.0371
# Epoch 55: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 234ms/step - categorical_accuracy: 0.9937 - loss: 0.0366 - val_categorical_accuracy: 0.9593 - val_loss: 0.1663
# Epoch 56/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - categorical_accuracy: 0.9949 - loss: 0.0344
# Epoch 56: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 79s 233ms/step - categorical_accuracy: 0.9949 - loss: 0.0343 - val_categorical_accuracy: 0.9615 - val_loss: 0.1523
# Epoch 57/100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - categorical_accuracy: 0.9942 - loss: 0.0344
# Epoch 57: val_loss did not improve from 0.13284
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 81s 238ms/step - categorical_accuracy: 0.9950 - loss: 0.0323 - val_categorical_accuracy: 0.9528 - val_loss: 0.1824
# Epoch 58/100
#  48/338 ━━━━━━━━━━━━━━━━━━━━ 1:05 225ms/step - categorical_accuracy: 0.9967 - loss: 0.0264
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_22970/2853166640.py in <cell line: 0>()
#      59     ]
#      60
# ---> 61     resnet152V2_history = resnet152V2_model.fit(
#      62         train_generator,
#      63         steps_per_epoch=N_STEPS,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in function(iterator)
#     240             ):
#     241                 opt_outputs = multi_step_on_iterator(iterator)
# --> 242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#     244                 return opt_outputs.get_value()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/optional_ops.py in has_value(self, name)
#     174   def has_value(self, name=None):
#     175     with ops.colocate_with(self._variant_tensor):
# --> 176       return gen_optional_ops.optional_has_value(
#     177           self._variant_tensor, name=name
#     178       )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_optional_ops.py in optional_has_value(optional, name)
#     170   if tld.is_eager:
#     171     try:
# --> 172       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     173         _ctx, "OptionalHasValue", name, optional)
#     174       return _result
#
# KeyboardInterrupt:

# %% [markdown]
# ## 7. Training History
#
# Plot the training/validation accuracy and loss curves for both stages,
# loaded from the CSV log files (persistent across restarts).

# %%
# Plot training history from CSV logs (works across Kaggle/session restarts)

def plot_from_log(log_path, title_prefix=''):
    """Plot training/validation accuracy and loss from a CSV log file."""
    df = pd.read_csv(log_path)

    plt.figure(figsize=(10, 5))

    plt.subplot(1, 2, 1)
    plt.plot(df['categorical_accuracy'], label='train')
    plt.plot(df['val_categorical_accuracy'], label='val')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.title(f'{title_prefix} Accuracy' if title_prefix else 'Accuracy')
    plt.legend(loc='upper left')

    plt.subplot(1, 2, 2)
    plt.plot(df['loss'], label='train')
    plt.plot(df['val_loss'], label='val')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.title(f'{title_prefix} Loss' if title_prefix else 'Loss')
    plt.legend(loc='upper left')

    plt.tight_layout()
    plt.show()

if os.path.exists(HEAD_LOG):
    print("--- Head-Only Training History ---")
    plot_from_log(HEAD_LOG, 'Head-Only')

if os.path.exists(FINETUNE_LOG):
    print("\n--- Fine-Tuning History ---")
    plot_from_log(FINETUNE_LOG, 'Fine-Tune')
# Out:
# --- Head-Only Training History ---
# --- Fine-Tuning History ---

# %% [markdown]
# ## 7. Evaluation
#
# Load the best checkpoint and evaluate on the held-out test set: overall
# accuracy/F2-score plus a per-class precision/recall/F-score breakdown.

# %%
resnet152V2_model.load_weights(FINETUNE_CHECKPOINT)

class_indices = train_generator.class_indices
class_indices = dict((v, k) for k, v in class_indices.items())

test_generator_new = test_gen.flow_from_directory(
    directory=TEST_DIR,
    target_size=(64, 64),
    batch_size=1,
    class_mode=None,
    color_mode='rgb',
    shuffle=False,
    seed=69,
)

predictions = resnet152V2_model.predict(
    test_generator_new, steps=len(test_generator_new.filenames)
)
predicted_classes = np.argmax(np.rint(predictions), axis=1)
true_classes = test_generator_new.classes

prf, conf_mat = display_results(true_classes, predicted_classes, class_indices.values())
prf
# Out:
# Found 5400 images belonging to 10 classes.
# 5400/5400 ━━━━━━━━━━━━━━━━━━━━ 104s 18ms/step
# Accuracy: 0.9648148148148148
# Macro F1 Score: 0.9639621281018222
# Global F2 Score: 0.9648148148148148
#                       Precision    Recall   F-Score  Support
# AnnualCrop             0.949097  0.963333  0.956162    600.0
# Forest                 0.981878  0.993333  0.987572    600.0
# HerbaceousVegetation   0.954315  0.940000  0.947103    600.0
# Highway                0.956349  0.964000  0.960159    500.0
# Industrial             0.991614  0.946000  0.968270    500.0
# Pasture                0.954887  0.952500  0.953692    400.0
# PermanentCrop          0.950413  0.920000  0.934959    500.0
# Residential            0.938967  1.000000  0.968523    600.0
# River                  0.973790  0.966000  0.969880    500.0
# SeaLake                0.998316  0.988333  0.993300    600.0

# %% [markdown]
# Confusion matrix for the per-class breakdown above:

# %%
conf_mat
# Out:
#                       AnnualCrop  Forest  HerbaceousVegetation  Highway  \
# AnnualCrop                   578       0                     0        1
# Forest                         1     596                     0        0
# HerbaceousVegetation           3       3                   564        3
# Highway                        6       0                     1      482
# Industrial                     2       0                     0        4
# Pasture                        7       4                     4        1
# PermanentCrop                  7       0                    21        2
# Residential                    0       0                     0        0
# River                          3       0                     1       11
# SeaLake                        2       4                     0        0
#
#                       Industrial  Pasture  PermanentCrop  Residential  River  \
# AnnualCrop                     1        6             13            0      1
# Forest                         0        2              0            0      1
# HerbaceousVegetation           0        8              9            9      1
# Highway                        0        1              1            1      8
# Industrial                   473        0              0           20      1
# Pasture                        0      381              1            2      0
# PermanentCrop                  3        1            460            6      0
# Residential                    0        0              0          600      0
# River                          0        0              0            1    483
# SeaLake                        0        0              0            0      1
#
#                       SeaLake
# AnnualCrop                  0
# Forest                      0
# HerbaceousVegetation        0
# Highway                     0
# Industrial                  0
# Pasture                     0
# PermanentCrop               0
# Residential                 0
# River                       1
# SeaLake                   593

# %% [markdown]
# A random sample of test images with predicted vs. true labels (green = correct, red = incorrect):

# %%
plot_predictions(true_classes, predictions, test_generator_new, class_indices)

# %% [markdown]
# ## 8. Save the Model
#
# Persist the fine-tuned model for later reuse or comparison against the other architectures.

# %%
resnet152V2_model.save(os.path.join(SAVE_DIR, 'ResNet152V2_eurosat.keras'))
np.save(os.path.join(SAVE_DIR, 'class_indices.npy'), train_generator.class_indices)

# Zip and download the results
import shutil
from google.colab import files

shutil.make_archive('EuroSAT_Training_Results', 'zip', SAVE_DIR)
files.download('EuroSAT_Training_Results.zip')
